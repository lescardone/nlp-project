# %%
import pandas as pd

# %%
df = pd.read_csv('files/article_items.csv',parse_dates=['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1344 non-null   int64
#  1   idx           1344 non-null   int64
#  2   date          1344 non-null   object
#  3   category      1338 non-null   object
#  4   authors       1344 non-null   object
#  5   title         1344 non-null   object
#  6   article_text  1344 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 73.6+ KB

# %% [markdown]
# # NNMF WORKFLOW

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_df = .80, min_df = 2, stop_words = 'english')

# %%
dtm = tfidf.fit_transform(df['article_text'])

# %% [markdown]
# ### Construct vector space model for documents (after stopword filtering), resulting in a document-term matrix A

# %%
from sklearn.decomposition import NMF

# %%
nmf = NMF(n_components=12, random_state=18)
nmf.fit(dtm)
# Out:
# /Users/lescardone/opt/anaconda3/envs/metis/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# /Users/lescardone/opt/anaconda3/envs/metis/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# NMF(n_components=12, random_state=18)

# %%
# Look at words/coefficients
len(tfidf.get_feature_names())
# holding an instance of every single word

# nfm.components_
# an array of coefficients per word per topic
# Out:
# 21866

# %% [markdown]
# ### Interpret topics based off the coefficient values of the words per topic

# %%
# Grab 15 words with highest coefficients per topic
for i, topic in enumerate(nmf.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC {i}:')
    print([tfidf.get_feature_names()[index] for index in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC 0:
# ['cases', 'dr', 'new', 'virus', 'medical', 'coronavirus', 'hospitals', 'pandemic', 'hospital', 'patients', 'care', '19', 'covid', 'says', 'health']
#
#
# THE TOP 15 WORDS FOR TOPIC 1:
# ['office', 'republican', 'election', 'vote', 'donald', 'pence', 'raskin', 'managers', 'senate', 'house', 'capitol', 'trial', 'president', 'impeachment', 'trump']
#
#
# THE TOP 15 WORDS FOR TOPIC 2:
# ['getty', 'riot', 'rioters', 'images', 'guard', 'law', 'enforcement', 'department', 'fbi', 'officer', 'security', 'jan', 'officers', 'police', 'capitol']
#
#
# THE TOP 15 WORDS FOR TOPIC 3:
# ['says', 'shot', 'shots', 'dose', 'johnson', 'moderna', 'health', 'vaccinated', 'pfizer', '19', 'vaccination', 'covid', 'doses', 'vaccines', 'vaccine']
#
#
# THE TOP 15 WORDS FOR TOPIC 4:
# ['tax', 'economy', 'package', 'white', 'infrastructure', 'congress', 'republicans', 'relief', 'plan', 'administration', 'senate', 'democrats', 'house', 'president', 'biden']
#
#
# THE TOP 15 WORDS FOR TOPIC 5:
# ['security', 'chinese', 'intelligence', 'world', 'military', 'npr', 'oil', 'agency', 'power', 'government', 'russia', 'says', 'pack', 'climate', 'china']
#
#
# THE TOP 15 WORDS FOR TOPIC 6:
# ['party', 'voter', 'senate', 'democrats', 'arizona', 'ballots', 'republicans', 'elections', 'republican', 'vote', 'state', 'voters', 'georgia', 'voting', 'election']
#
#
# THE TOP 15 WORDS FOR TOPIC 7:
# ['jury', 'blackwell', 'murder', 'court', 'death', 'nelson', 'george', 'derek', 'trial', 'officer', 'minneapolis', 'officers', 'police', 'chauvin', 'floyd']
#
#
# THE TOP 15 WORDS FOR TOPIC 8:
# ['killed', 'rocket', 'militants', 'violence', 'arab', 'israelis', 'netanyahu', 'rockets', 'jerusalem', 'hamas', 'palestinians', 'palestinian', 'gaza', 'israeli', 'israel']
#
#
# THE TOP 15 WORDS FOR TOPIC 9:
# ['npr', 'student', 'person', 'children', 'like', 'parents', 'college', 'education', 'kids', 'learning', 'teachers', 'says', 'schools', 'school', 'students']
#
#
# THE TOP 15 WORDS FOR TOPIC 10:
# ['results', 'federal', 'law', 'numbers', 'unauthorized', 'data', 'administration', 'apportionment', 'immigrants', 'count', 'supreme', 'trump', 'court', 'bureau', 'census']
#
#
# THE TOP 15 WORDS FOR TOPIC 11:
# ['apple', 'platforms', 'misinformation', 'trump', 'users', 'zuckerberg', 'companies', 'google', 'content', 'tech', 'twitter', 'social', 'media', 'company', 'facebook']

# %% [markdown]
# ### Assign to Docs

# %%
topic_results = nmf.transform(dtm).round(3)
df['topic_num'] = topic_results.argmax(axis=1)

# %%
topic_results.shape
# Out:
# (1344, 12)

# %%
topic_results[0]
# Out:
# array([0.014, 0.   , 0.01 , 0.   , 0.   , 0.019, 0.005, 0.004, 0.001,
#        0.031, 0.   , 0.   ])

# %%
df['category'] = df['category'].apply(lambda x: str(x).strip())

# %%
df[['title','category','topic_num']].head()
# Out:
#                                                title     category  topic_num
# 0  The Army Is Expanding Allowed Hairstyles For W...     National          9
# 1  Once Nearly Extinct, The Florida Panther Is Ma...  Environment          5
# 2  What The Rise Of Amazon Has To Do With The Ris...     Politics         11
# 3           The Youth Of Cuba's Tiny Jewish Minority     Politics          9
# 4  Melting Snow Usually Means Water For The West....  Environment          5

# %%
df.groupby(['category'])['topic_num'].apply(lambda grp: list(grp.value_counts().index)).to_dict()
# Out:
# {'50 Years Of NPR': [9],
#  'Africa': [0, 9],
#  'America Reckons With Racial Injustice': [7, 2, 9, 5, 4],
#  'Analysis': [4, 1, 2],
#  'Animals': [9, 5, 0],
#  'Architecture': [0, 5],
#  'Arts & Life': [9],
#  'Asia': [5, 2],
#  'Author Interviews': [9, 4, 11],
#  'Biden Transition Updates': [4, 9, 6, 1, 5],
#  'Bill Of The Month': [0],
#  'Book Reviews': [0],
#  'Books': [9, 1],
#  'Business': [11, 5, 9, 4, 0, 2, 10],
#  'Capitol Insurrection Updates': [2],
#  'Code Switch': [0],
#  'Congress Weighs Action Against Trump: Live Updates': [1, 2],
#  "Congress' Electoral College Tally: Live Updates": [1, 2],
#  'Consider This from NPR': [9, 3],
#  'Coronavirus By The Numbers': [0, 3],
#  'Coronavirus Guide': [0, 9],
#  'Coronavirus Live Updates': [9, 0, 11],
#  'Coronavirus Updates': [0, 3, 9, 1, 2, 4, 5, 11],
#  'Coronavirus, Illustrated': [0, 3],
#  'Criminal Justice Collaborative': [2, 7, 0, 4],
#  'Culture': [5],
#  'Development': [5],
#  'Discipline And Women In Prison': [4],
#  'Economics': [0],
#  'Economy': [4, 0, 5, 9],
#  "Editors' Picks": [4, 9],
#  'Education': [9, 3],
#  'Elections': [6, 1, 2, 4, 5, 11],
#  'Embedded': [5],
#  'Energy': [5],
#  'Enough Already: How The Pandemic Is Breaking Women': [9],
#  'Environment': [5, 0, 9],
#  'Environment And Energy Collaborative': [5],
#  'Europe': [5, 2],
#  'Fall 2020 College Road Trip': [9],
#  'Family': [9, 11],
#  'Food': [9, 5],
#  'Games': [9],
#  'Global Health': [0],
#  'Goats and Soda': [0, 3, 9, 5, 8],
#  'Health': [0, 11, 3, 5, 7],
#  'Health Care': [0],
#  'Health Inc.': [0, 9, 3],
#  'History': [9, 4],
#  'House Impeachment Vote: Live Updates': [1],
#  'How I Built This with Guy Raz': [9],
#  'Inauguration Day: Live Updates': [4, 2],
#  'Infectious Disease': [3, 9],
#  'Insurrection At The Capitol: Live Updates': [2, 1, 8, 11],
#  'Investigations': [0, 2, 5, 3, 9, 11, 4, 7, 10],
#  'Kitchen Table Conversations': [9],
#  'Latin America': [4, 5],
#  'Law': [10, 2, 9, 7, 6, 1, 5, 0, 3, 11],
#  'Life Kit': [9],
#  'Live Updates: Protests For Racial Justice': [2, 9],
#  "Live Updates: Trial Over George Floyd's Killing": [7],
#  'Live Updates: Winter Storms 2021': [5],
#  'Media': [5, 1, 9, 11],
#  'Mental Health': [9],
#  'Middle East': [8, 5, 0, 9],
#  'Movie Interviews': [9],
#  'Movies': [11],
#  'Music': [9, 5],
#  'Music News': [9, 5, 2],
#  'NPR Ed': [9],
#  'National': [9, 2, 0, 5, 10, 4, 11, 3, 7, 6, 1, 8],
#  'National Security': [5, 2, 0, 4, 11],
#  'Obituaries': [9, 5, 4, 7],
#  'On Disabilities': [9],
#  'Photography': [3],
#  'Planet Money': [8, 9],
#  'Policy-ish': [0, 10, 4, 6],
#  'Politics': [4, 1, 6, 2, 5, 9, 11, 0, 3, 8, 7, 10],
#  'Pop Culture': [11],
#  'President Biden Takes Office': [9, 5, 4],
#  'Public Health': [0, 3, 5, 9],
#  'Race': [2, 7, 5, 9],
#  'Religion': [5, 9, 2],
#  'Science': [5, 9],
#  'Shots - Health News': [3, 0, 9, 5, 1, 4],
#  'Slingshot': [9],
#  'Space': [5],
#  'Sports': [9, 5, 6, 11],
#  'StoryCorps': [9],
#  'Strange News': [9],
#  'Student Podcast Challenge': [9],
#  'Take A Number': [0],
#  'Technology': [11, 9, 5],
#  'Television': [9],
#  'The Coronavirus Crisis': [0, 3, 9, 4, 5, 2, 1, 6, 8, 11],
#  'The Picture Show': [2],
#  'Treatments': [0, 3, 9],
#  'Trump Impeachment Trial: Live Updates': [1],
#  'Untangling Disinformation': [11, 9, 4],
#  'Weather': [5, 9],
#  'Women & Girls': [9],
#  'World': [5, 9, 8, 0, 2, 1],
#  'Your Health': [9, 0, 3],
#  'Your Money': [9, 5],
#  'Youth': [0],
#  'nan': [0, 9, 3]}

# %% [markdown]
# ### NNMF Topic as Corresponding to Assigned Category

# %%
df.groupby(['topic_num'])['category'].apply(lambda grp: list(grp.value_counts().index)).to_dict()
# Out:
# {0: ['The Coronavirus Crisis',
#   'National',
#   'Goats and Soda',
#   'Treatments',
#   'Shots - Health News',
#   'Health',
#   'Coronavirus Updates',
#   'Investigations',
#   'Public Health',
#   'Policy-ish',
#   'Business',
#   'World',
#   'Bill Of The Month',
#   'Coronavirus Live Updates',
#   'Politics',
#   'Your Health',
#   'Environment',
#   'Health Inc.',
#   'Health Care',
#   'nan',
#   'Economy',
#   'Coronavirus, Illustrated',
#   'Youth',
#   'Economics',
#   'Middle East',
#   'Global Health',
#   'Animals',
#   'Book Reviews',
#   'Coronavirus By The Numbers',
#   'Criminal Justice Collaborative',
#   'Take A Number',
#   'Architecture',
#   'Coronavirus Guide',
#   'Africa',
#   'National Security',
#   'Code Switch',
#   'Law'],
#  1: ['Politics',
#   'Trump Impeachment Trial: Live Updates',
#   'Congress Weighs Action Against Trump: Live Updates',
#   'National',
#   'Media',
#   'Insurrection At The Capitol: Live Updates',
#   'Elections',
#   'Law',
#   'Analysis',
#   'Biden Transition Updates',
#   'House Impeachment Vote: Live Updates',
#   'Coronavirus Updates',
#   "Congress' Electoral College Tally: Live Updates",
#   'The Coronavirus Crisis',
#   'Shots - Health News',
#   'Books',
#   'World'],
#  2: ['National',
#   'Politics',
#   'Law',
#   'America Reckons With Racial Injustice',
#   'National Security',
#   'Investigations',
#   'Race',
#   'The Coronavirus Crisis',
#   'Insurrection At The Capitol: Live Updates',
#   'Europe',
#   'Live Updates: Protests For Racial Justice',
#   'The Picture Show',
#   'Criminal Justice Collaborative',
#   'World',
#   'Asia',
#   'Congress Weighs Action Against Trump: Live Updates',
#   'Coronavirus Updates',
#   "Congress' Electoral College Tally: Live Updates",
#   'Music News',
#   'Religion',
#   'Capitol Insurrection Updates',
#   'Business',
#   'Analysis',
#   'Inauguration Day: Live Updates',
#   'Elections'],
#  3: ['The Coronavirus Crisis',
#   'Shots - Health News',
#   'National',
#   'Goats and Soda',
#   'Infectious Disease',
#   'Coronavirus Updates',
#   'Public Health',
#   'Politics',
#   'Your Health',
#   'Investigations',
#   'nan',
#   'Coronavirus, Illustrated',
#   'Treatments',
#   'Education',
#   'Health',
#   'Law',
#   'Health Inc.',
#   'Coronavirus By The Numbers',
#   'Consider This from NPR',
#   'Photography'],
#  4: ['Politics',
#   'National',
#   'Biden Transition Updates',
#   'The Coronavirus Crisis',
#   'Analysis',
#   'Business',
#   'Economy',
#   'Inauguration Day: Live Updates',
#   'Author Interviews',
#   'Latin America',
#   'History',
#   'Untangling Disinformation',
#   'America Reckons With Racial Injustice',
#   'Shots - Health News',
#   "Editors' Picks",
#   'Coronavirus Updates',
#   'Discipline And Women In Prison',
#   'Obituaries',
#   'Elections',
#   'Criminal Justice Collaborative',
#   'Policy-ish',
#   'President Biden Takes Office',
#   'Investigations',
#   'National Security'],
#  5: ['World',
#   'National Security',
#   'National',
#   'Politics',
#   'Environment',
#   'Asia',
#   'Science',
#   'Business',
#   'Live Updates: Winter Storms 2021',
#   'Middle East',
#   'Europe',
#   'The Coronavirus Crisis',
#   'Weather',
#   'Media',
#   'Energy',
#   'Investigations',
#   'Obituaries',
#   'Public Health',
#   'Goats and Soda',
#   'Sports',
#   'Space',
#   'America Reckons With Racial Injustice',
#   'Latin America',
#   'Economy',
#   'Technology',
#   'Shots - Health News',
#   'Religion',
#   'Law',
#   'Animals',
#   'Culture',
#   'Race',
#   'Health',
#   'Your Money',
#   'Food',
#   'Environment And Energy Collaborative',
#   'Architecture',
#   'Music',
#   'Biden Transition Updates',
#   'Coronavirus Updates',
#   'Music News',
#   'President Biden Takes Office',
#   'Development',
#   'Elections',
#   'Embedded'],
#  6: ['Politics',
#   'Elections',
#   'Law',
#   'National',
#   'Biden Transition Updates',
#   'Sports',
#   'The Coronavirus Crisis',
#   'Policy-ish'],
#  7: ['America Reckons With Racial Injustice',
#   'National',
#   'Law',
#   'Criminal Justice Collaborative',
#   'Race',
#   "Live Updates: Trial Over George Floyd's Killing",
#   'Obituaries',
#   'Politics',
#   'Health',
#   'Investigations'],
#  8: ['Middle East',
#   'World',
#   'Politics',
#   'Goats and Soda',
#   'National',
#   'The Coronavirus Crisis',
#   'Insurrection At The Capitol: Live Updates',
#   'Planet Money'],
#  9: ['National',
#   'The Coronavirus Crisis',
#   'Education',
#   'Sports',
#   'Politics',
#   'Business',
#   'Obituaries',
#   'Law',
#   'World',
#   'America Reckons With Racial Injustice',
#   'Your Health',
#   'Shots - Health News',
#   'Goats and Soda',
#   'Author Interviews',
#   'Coronavirus Live Updates',
#   'Coronavirus Updates',
#   'On Disabilities',
#   'Animals',
#   'Biden Transition Updates',
#   'Music',
#   'Technology',
#   'nan',
#   'Economy',
#   'History',
#   'Public Health',
#   'Investigations',
#   'Life Kit',
#   'Books',
#   'Games',
#   'Kitchen Table Conversations',
#   'Family',
#   'Live Updates: Protests For Racial Justice',
#   'Race',
#   'Fall 2020 College Road Trip',
#   'Student Podcast Challenge',
#   'Weather',
#   'Food',
#   'President Biden Takes Office',
#   'Religion',
#   'Environment',
#   'Music News',
#   'Health Inc.',
#   'Africa',
#   'StoryCorps',
#   'Untangling Disinformation',
#   'How I Built This with Guy Raz',
#   'Science',
#   'Movie Interviews',
#   'Media',
#   '50 Years Of NPR',
#   'Arts & Life',
#   'Planet Money',
#   "Editors' Picks",
#   'Television',
#   'Enough Already: How The Pandemic Is Breaking Women',
#   'Mental Health',
#   'Infectious Disease',
#   'Middle East',
#   'Coronavirus Guide',
#   'Strange News',
#   'Treatments',
#   'NPR Ed',
#   'Women & Girls',
#   'Your Money',
#   'Consider This from NPR',
#   'Slingshot'],
#  10: ['National',
#   'Law',
#   'Policy-ish',
#   'Investigations',
#   'Politics',
#   'Business'],
#  11: ['Technology',
#   'National',
#   'Business',
#   'Politics',
#   'Untangling Disinformation',
#   'Investigations',
#   'Health',
#   'Author Interviews',
#   'Insurrection At The Capitol: Live Updates',
#   'Movies',
#   'The Coronavirus Crisis',
#   'Coronavirus Live Updates',
#   'Coronavirus Updates',
#   'Media',
#   'National Security',
#   'Family',
#   'Pop Culture',
#   'Law',
#   'Elections',
#   'Sports']}

# %%
# map the topic numbers to words/topic descriptors
# nterpret topics based off the coefficent values of the words per topic

# %% [markdown]
# # Readability

# %%
import textstat

# %%
df['f_r_e'] = df['article_text'].apply(lambda x: textstat.flesch_reading_ease(x))

# %%
df['ari_grade_level'] = df['article_text'].apply(lambda x: textstat.automated_readability_index(x))

# %%
df[['title','article_text','topic_num','f_r_e','ari_grade_level']]
# Out:
#                                                   title  \
# 0     The Army Is Expanding Allowed Hairstyles For W...
# 1     Once Nearly Extinct, The Florida Panther Is Ma...
# 2     What The Rise Of Amazon Has To Do With The Ris...
# 3              The Youth Of Cuba's Tiny Jewish Minority
# 4     Melting Snow Usually Means Water For The West....
# ...                                                 ...
# 1339  President-Elect Biden Names Core Members Of Hi...
# 1340  Moderna's COVID-19 Vaccine Candidate Gets More...
# 1341  As Hospitals Fill With COVID-19 Patients, Medi...
# 1342  IRS Says Its Own Error Sent $1,200 Stimulus Ch...
# 1343  With 2020 Called A Success, Big Questions Lie ...
#
#                                            article_text  topic_num  f_r_e  \
# 0     Enlarge this image An Army photo shows a soldi...          9  69.01
# 1     Enlarge this image A male panther leaps over a...          5  66.27
# 2     Enlarge this image Members of the Workers Asse...         11  63.43
# 3     Enlarge this image Adri Quiñones, center, lead...          9  58.82
# 4     Enlarge this image Colorado Snow Survey superv...          5  51.82
# ...                                                 ...        ...    ...
# 1339  Enlarge this image President-elect Joe Biden h...          4  49.45
# 1340  Enlarge this image Moderna protocol files for ...          3  46.91
# 1341  Enlarge this image Tennessee Gov. Bill Lee (ri...          0  57.71
# 1342  Enlarge this image An error at the IRS caused ...          4  51.82
# 1343  Enlarge this image After a highly fraught but ...          6  47.01
#
#       ari_grade_level
# 0                11.2
# 1                12.3
# 2                12.9
# 3                13.2
# 4                16.3
# ...               ...
# 1339             14.3
# 1340             14.5
# 1341             14.0
# 1342             16.0
# 1343             16.1
#
# [1344 rows x 5 columns]

# %%
df.groupby(['topic_num'])['f_r_e'].mean()
# Out:
# topic_num
# 0     54.303269
# 1     51.942933
# 2     50.501759
# 3     51.028760
# 4     48.928742
# 5     50.338850
# 6     49.140392
# 7     55.394375
# 8     49.300435
# 9     58.325023
# 10    45.505938
# 11    49.446667
# Name: f_r_e, dtype: float64
